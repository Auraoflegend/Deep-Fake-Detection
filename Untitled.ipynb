# %%
import tensorflow as tf
import os
import numpy as np 
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D, Dense, Flatten
import cv2

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tg.config.experimental.set_memory_growth(gpu,True)

# %%
data = tf.keras.utils.image_dataset_from_directory('train')
# Out:
# Found 1920 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
#image represented as  numpy
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
fig, ax= plt.subplots(ncols=4, figsize=(20,40))
for idx,img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
# 0 for fake  #1 for real

# %%
#preprocessing  / 255 scaling

# %%
data = data.map(lambda x,y:(x/255,y))

# %% [markdown]
# # split

# %%
len(data)
# Out:
# 60

# %%
train_size = int (len(data)*.7)
val_size = int (len(data)*.2)
test_size= int(len(data)*.1)

# %%
train_size+test_size+val_size
# Out:
# 60

# %%
train = data.take(train_size)
val= data.skip(train_size).take(val_size)
test= data.skip(train_size+val_size).take(test_size)

# %%
len(test)
# Out:
# 6

# %% [markdown]
# # deep learning

# %% [markdown]
# ### Build Deep learning model

# %%
model = Sequential()

# %%
model.add(Conv2D(16,(3,3),1,activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# ## Train

# %%
from keras.callbacks import EarlyStopping

# %%
hist = model.fit(train,epochs=20,validation_data=val,callbacks=EarlyStopping())
# Out:
# Epoch 1/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 424ms/step - accuracy: 0.5847 - loss: 0.8425 - val_accuracy: 0.7865 - val_loss: 0.4748
# Epoch 2/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 383ms/step - accuracy: 0.8290 - loss: 0.3896 - val_accuracy: 0.8854 - val_loss: 0.2845
# Epoch 3/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 387ms/step - accuracy: 0.8980 - loss: 0.2299 - val_accuracy: 0.9036 - val_loss: 0.2387
# Epoch 4/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 383ms/step - accuracy: 0.9248 - loss: 0.1759 - val_accuracy: 0.8828 - val_loss: 0.2463

# %% [markdown]
# # performance

# %%
from tensorflow.keras.metrics import Precision, Recall , BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
    X,y =batch
    yhat = model.predict(X)
    pre.update_state(y,yhat)
    re.update_state(y,yhat)
    acc.update_state(y,yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step

# %%
print(f'Precision:{pre.result().numpy()*100},Recall:{re.result().numpy()*100},Accuracy:{acc.result().numpy()*100}')
# Out:
# Precision:93.9393937587738,Recall:87.73584961891174,Accuracy:90.10416865348816

# %% [markdown]
# # test

# %%
img = cv2.imread('test/')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img,(256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
np.expand_dims(resize,0).shape
# Out:
# (1, 256, 256, 3)

# %%
yhat = model.predict(np.expand_dims(resize/255,0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step

# %%
yhat
# Out:
# array([[0.9091323]], dtype=float32)

# %%
if yhat > 0.5:
    print(f' Predicted class is original')
else:
    print(f'Predicted class is deepfake')
# Out:
#  Predicted class is original

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','deepfakemodel.h5'))
